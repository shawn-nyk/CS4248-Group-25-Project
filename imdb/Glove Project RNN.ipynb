# %%
# %cd "OneDrive - National University of Singapore"
# Out:
# C:\Users\wongp\OneDrive - National University of Singapore

# %%
# %cd CS4248/Project/db/
# Out:
# C:\Users\wongp\OneDrive - National University of Singapore\CS4248\Project\db

# %%
import os
import pandas as pd
import numpy as np
from nltk.tokenize import word_tokenize
from collections import Counter
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split

# %% [markdown]
# Convert training data into csv file

# %%
import os
import pandas as pd

pathNeg = "train/neg"
files = os.listdir(pathNeg)
data = []
for file in files:
  if os.path.isfile(os.path.join(pathNeg, file)):
    id = int(file.split("_")[0])
    with open(os.path.join(pathNeg, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 0])

sizeOfNeg = 12500

pathPos = "train/pos"
files = os.listdir(pathPos)
for file in files:
  if os.path.isfile(os.path.join(pathPos, file)):
    id = int(file.split("_")[0]) + sizeOfNeg
    with open(os.path.join(pathPos, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 1])


df = pd.DataFrame(data, columns = ['id', 'text', 'score']).set_index('id').sort_index()
df.to_csv('train.csv')

# %% [markdown]
# Convert testing data into csv file

# %%
pathNeg = "test/neg"
files = os.listdir(pathNeg)
data = []
for file in files:
  if os.path.isfile(os.path.join(pathNeg, file)):
    id = int(file.split("_")[0])
    with open(os.path.join(pathNeg, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 0])

sizeOfNeg = 12500

pathPos = "test/pos"
files = os.listdir(pathPos)
for file in files:
  if os.path.isfile(os.path.join(pathPos, file)):
    id = int(file.split("_")[0]) + sizeOfNeg
    with open(os.path.join(pathPos, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 1])


df = pd.DataFrame(data, columns = ['id', 'text', 'score']).set_index('id').sort_index()
df.to_csv('test.csv')

# %% [markdown]
# convert vocab into csv file

# %%
with open("imdb.vocab", encoding='utf8') as f:
  vocab = []
  for line in f:
    vocab.append(line.rstrip())

vocab_df = pd.DataFrame(vocab, columns=['vocab'])
print(vocab_df)
vocab_df.to_csv('vocab_given.csv', index=False)
# Out:
#                    vocab
# 0                    the
# 1                    and
# 2                      a
# 3                     of
# 4                     to
# ...                  ...
# 89522          copywrite
# 89523             artbox
# 89524          kinky-sex
# 89525           urrrghhh
# 89526  investigator-like
#
# [89527 rows x 1 columns]

# %%
from nltk.tokenize import word_tokenize

def tokenizeReview(review):
  review = review.replace('.', ' . ')
  tokens = word_tokenize(review.lower())
  return tokens

# %% [markdown]
# Get vocab from training set

# %%
from collections import Counter
reviews = train_df['text'].tolist()
reviews = list(map(tokenizeReview, reviews))
reviews = [item for review in reviews for item in review]
vdict = Counter(reviews).most_common()

# %%
vocabs = []
for pair in vdict:
  vocabs.append(pair[0])

vocab_df = pd.DataFrame(vocabs, columns=['vocab'])
vocab_df.to_csv('vocab.csv', index=False)
print(vocab_df)
# Out:
#               vocab
# 0               the
# 1                 .
# 2                 ,
# 3               and
# 4                 a
# ...             ...
# 99203    people-and
# 99204         padre
# 99205   unmatchable
# 99206  scenery-wise
# 99207  non-teenager
#
# [99208 rows x 1 columns]

# %% [markdown]
# Read training data and testing data from csv file (START HERE after initialization)

# %%
train_df = pd.read_csv('train/train.csv')
test_df = pd.read_csv('test/test.csv')
vocab_df = pd.read_csv('vocab.csv')
print(vocab_df)
# Out:
#               vocab
# 0               the
# 1                 .
# 2                 ,
# 3               and
# 4                 a
# ...             ...
# 99203    people-and
# 99204         padre
# 99205   unmatchable
# 99206  scenery-wise
# 99207  non-teenager
#
# [99208 rows x 1 columns]

# %%
vocab_dict = pd.Series(vocab_df.index + 1, index=vocab_df.vocab).to_dict()
print(vocab_dict)

# %%
def convertToIndex(review):
  vec = []
  for word in review:
    if word in vocab_dict:
      vec.append(int(vocab_dict[word]))
    else:
      vec.append(0)
  return vec

# %%
train_df['tokens'] = train_df['text'].apply(tokenizeReview)

# %%
train_df['vec'] = train_df['tokens'].apply(convertToIndex)

# %%
train_df
# Out:
#           id                                               text  score  \
# 0          0  Story of a man who has unnatural feelings for ...      0
# 1          1  Robert DeNiro plays the most unbelievably inte...      0
# 2          2  I saw the capsule comment said "great acting."...      0
# 3          3  If I had not read Pat Barker's 'Union Street' ...      0
# 4          4  This fanciful horror flick has Vincent Price p...      0
# ...      ...                                                ...    ...
# 24995  24995  What's Good About It: Some inventive and genui...      1
# 24996  24996  For years we've been watching every horror fil...      1
# 24997  24997  If you haven't already seen this movie of Mary...      1
# 24998  24998  this movie is the best movie ever it has a lot...      1
# 24999  24999  I always feel strange and guilty saying it (be...      1
#
#                                                   tokens  \
# 0      [story, of, a, man, who, has, unnatural, feeli...
# 1      [robert, deniro, plays, the, most, unbelievabl...
# 2      [i, saw, the, capsule, comment, said, ``, grea...
# 3      [if, i, had, not, read, pat, barker, 's, 'unio...
# 4      [this, fanciful, horror, flick, has, vincent, ...
# ...                                                  ...
# 24995  [what, 's, good, about, it, :, some, inventive...
# 24996  [for, years, we, 've, been, watching, every, h...
# 24997  [if, you, have, n't, already, seen, this, movi...
# 24998  [this, movie, is, the, best, movie, ever, it, ...
# 24999  [i, always, feel, strange, and, guilty, saying...
#
#                                                      vec
# 0      [76, 6, 5, 142, 46, 56, 7518, 1387, 21, 5, 451...
# 1      [649, 5006, 307, 1, 106, 3769, 1076, 9203, 6, ...
# 2      [15, 226, 1, 9586, 906, 311, 28, 102, 129, 2, ...
# 3      [57, 15, 78, 32, 338, 3189, 7720, 18, 34296, 8...
# 4      [16, 16016, 213, 512, 56, 3154, 1789, 397, 5, ...
# ...                                                  ...
# 24995  [60, 18, 62, 55, 13, 87, 61, 4388, 4, 2028, 93...
# 24996  [21, 168, 82, 155, 93, 163, 188, 213, 25, 17, ...
# 24997  [57, 29, 37, 31, 466, 126, 16, 23, 6, 13586, 4...
# 24998  [16, 23, 8, 1, 133, 23, 138, 13, 56, 5, 186, 6...
# 24999  [15, 222, 248, 669, 4, 2490, 653, 13, 27, 101,...
#
# [25000 rows x 5 columns]

# %%
print('Maximum review length: {}'.format(
len(max((train_df['tokens']), key=len))))
print('Minimum review length: {}'.format(
len(min((train_df['tokens']), key=len))))
# Out:
# Maximum review length: 2820
# Minimum review length: 11

# %%
max_words = 500
dataset = sequence.pad_sequences(train_df['vec'], maxlen=max_words)
y = train_df['score']

# %%
X_train, X_val, y_train, y_val = train_test_split(dataset, y, test_size=0.3, stratify=y, random_state = 42)

# %%
from gensim.models import Word2Vec
import gensim.downloader as api

v2w_model = api.load('glove-wiki-gigaword-50')
print(v2w_model['computer'])
# Out:
# [ 0.079084 -0.81504   1.7901    0.91653   0.10797  -0.55628  -0.84427
#  -1.4951    0.13418   0.63627   0.35146   0.25813  -0.55029   0.51056
#   0.37409   0.12092  -1.6166    0.83653   0.14202  -0.52348   0.73453
#   0.12207  -0.49079   0.32533   0.45306  -1.585    -0.63848  -1.0053
#   0.10454  -0.42984   3.181    -0.62187   0.16819  -1.0139    0.064058
#   0.57844  -0.4556    0.73783   0.37203  -0.57722   0.66441   0.055129
#   0.037891  1.3275    0.30991   0.50697   1.2357    0.1274   -0.11434
#   0.20709 ]

# %%
embedding_dim = 100
vocab_len = len(vocab_dict) + 1
embed_vector_len = v2w_model['computer'].shape[0]
emb_matrix = np.zeros((vocab_len, embed_vector_len))

for word, i in vocab_dict.items():
  if word in v2w_model:
    embedding_vector = v2w_model.get_vector(word)
    emb_matrix[i] = embedding_vector

# %%
emb_matrix[1]
# Out:
# array([ 4.18000013e-01,  2.49679998e-01, -4.12420005e-01,  1.21699996e-01,
#         3.45270008e-01, -4.44569997e-02, -4.96879995e-01, -1.78619996e-01,
#        -6.60229998e-04, -6.56599998e-01,  2.78430015e-01, -1.47670001e-01,
#        -5.56770027e-01,  1.46579996e-01, -9.50950012e-03,  1.16579998e-02,
#         1.02040000e-01, -1.27920002e-01, -8.44299972e-01, -1.21809997e-01,
#        -1.68009996e-02, -3.32789987e-01, -1.55200005e-01, -2.31309995e-01,
#        -1.91809997e-01, -1.88230002e+00, -7.67459989e-01,  9.90509987e-02,
#        -4.21249986e-01, -1.95260003e-01,  4.00710011e+00, -1.85939997e-01,
#        -5.22870004e-01, -3.16810012e-01,  5.92130003e-04,  7.44489999e-03,
#         1.77780002e-01, -1.58969998e-01,  1.20409997e-02, -5.42230010e-02,
#        -2.98709989e-01, -1.57490000e-01, -3.47579986e-01, -4.56370004e-02,
#        -4.42510009e-01,  1.87849998e-01,  2.78489990e-03, -1.84110001e-01,
#        -1.15139998e-01, -7.85809994e-01])

# %%
print(vocab_len)
# Out:
# 99208

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU

embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=max_words, weights=[emb_matrix], trainable=False)

embedding_size=32
model=Sequential()
model.add(embedding_layer)
model.add(GRU(units=50, return_sequences = True, input_shape=(X_train.shape[1],1), activation='tanh'))
#model.add(LSTM(100))
model.add(Dropout(0.6))
model.add(GRU(units=50, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_5 (Embedding)     (None, 500, 50)           4960400
#
#  gru_3 (GRU)                 (None, 500, 50)           15300
#
#  dropout (Dropout)           (None, 500, 50)           0
#
#  gru_4 (GRU)                 (None, 50)                15300
#
#  dense_3 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 4,991,051
# Trainable params: 30,651
# Non-trainable params: 4,960,400
# _________________________________________________________________
# None

# %%
batch_size=32
model.fit(X_train, y_train, epochs = 5, batch_size=batch_size, verbose = 'auto')
# Out:
# Epoch 1/5
# 547/547 [==============================] - 128s 230ms/step - loss: 0.5820 - accuracy: 0.6815
# Epoch 2/5
# 547/547 [==============================] - 127s 232ms/step - loss: 0.4186 - accuracy: 0.8129
# Epoch 3/5
# 547/547 [==============================] - 125s 228ms/step - loss: 0.3704 - accuracy: 0.8382
# Epoch 4/5
# 547/547 [==============================] - 125s 228ms/step - loss: 0.3450 - accuracy: 0.8542
# Epoch 5/5
# 547/547 [==============================] - 127s 231ms/step - loss: 0.3218 - accuracy: 0.8645

# %%
scores = model.evaluate(X_val, y_val, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Test accuracy: 0.8615999817848206

# %%
model.save('basic_model')
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: basic_gru_model\assets
# INFO:tensorflow:Assets written to: basic_gru_model\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x0000023D12CBCC70> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %% [markdown]
# **Without Glove word embedding**

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU
embedding_size=32
model=Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_words))
model.add(GRU(units=50, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_9 (Embedding)     (None, 500, 32)           3174656
#
#  gru_9 (GRU)                 (None, 50)                12600
#
#  dense_8 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 3,187,307
# Trainable params: 3,187,307
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size=32
model.fit(X_train, y_train, epochs = 5, batch_size=batch_size, verbose = 'auto')
# Out:
# Epoch 1/5
# 547/547 [==============================] - 75s 134ms/step - loss: 0.5092 - accuracy: 0.7413
# Epoch 2/5
# 547/547 [==============================] - 73s 134ms/step - loss: 0.2315 - accuracy: 0.9130
# Epoch 3/5
# 547/547 [==============================] - 73s 134ms/step - loss: 0.1140 - accuracy: 0.9619
# Epoch 4/5
# 547/547 [==============================] - 73s 133ms/step - loss: 0.0594 - accuracy: 0.9807
# Epoch 5/5
# 547/547 [==============================] - 72s 132ms/step - loss: 0.0554 - accuracy: 0.9798

# %%
scores = model.evaluate(X_val, y_val, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Test accuracy: 0.8438666462898254

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU
embedding_size=32
model=Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_words))
#model.add(GRU(units=50, input_shape=(X_train.shape[1],1), activation='tanh'))
model.add(GRU(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())

batch_size=32
model.fit(X_train, y_train, epochs = 5, batch_size=batch_size, verbose = 'auto')

scores = model.evaluate(X_val, y_val, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Model: "sequential_14"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_13 (Embedding)    (None, 500, 32)           3174656
#
#  gru_13 (GRU)                (None, 100)               40200
#
#  dense_12 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 3,214,957
# Trainable params: 3,214,957
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/5
# 547/547 [==============================] - 94s 170ms/step - loss: 0.5660 - accuracy: 0.7101
# Epoch 2/5
# 547/547 [==============================] - 92s 168ms/step - loss: 0.2973 - accuracy: 0.8813
# Epoch 3/5
# 547/547 [==============================] - 92s 168ms/step - loss: 0.1586 - accuracy: 0.9445
# Epoch 4/5
# 547/547 [==============================] - 92s 168ms/step - loss: 0.0904 - accuracy: 0.9711
# Epoch 5/5
# 547/547 [==============================] - 93s 170ms/step - loss: 0.0694 - accuracy: 0.9782
# Test accuracy: 0.8522666692733765

# %% [markdown]
# # Testing Dataset

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU

embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=max_words, weights=[emb_matrix], trainable=True)

embedding_size=32
model=Sequential()
model.add(embedding_layer)
model.add(GRU(units=50, return_sequences = True, input_shape=(dataset.shape[1],1), activation='tanh'))
#model.add(LSTM(100))
model.add(Dropout(0.6))
model.add(GRU(units=50, input_shape=(dataset.shape[1],1), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 500, 50)           4960400
#
#  gru (GRU)                   (None, 500, 50)           15300
#
#  dropout (Dropout)           (None, 500, 50)           0
#
#  gru_1 (GRU)                 (None, 50)                15300
#
#  dense (Dense)               (None, 1)                 51
#
# =================================================================
# Total params: 4,991,051
# Trainable params: 4,991,051
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size=32
model.fit(dataset, y, epochs = 5, batch_size=batch_size, verbose = 'auto')
# Out:
# Epoch 1/5
# 782/782 [==============================] - 204s 259ms/step - loss: 0.4796 - accuracy: 0.7501
# Epoch 2/5
# 782/782 [==============================] - 200s 256ms/step - loss: 0.2342 - accuracy: 0.9076
# Epoch 3/5
# 782/782 [==============================] - 197s 252ms/step - loss: 0.1278 - accuracy: 0.9561
# Epoch 4/5
# 782/782 [==============================] - 197s 252ms/step - loss: 0.0591 - accuracy: 0.9819
# Epoch 5/5
# 782/782 [==============================] - 199s 254ms/step - loss: 0.0266 - accuracy: 0.9936

# %%
test_df['tokens'] = test_df['text'].apply(tokenizeReview)
test_df['vec'] = test_df['tokens'].apply(convertToIndex)
test_x = sequence.pad_sequences(test_df['vec'], maxlen=max_words)
test_x
# Out:
# array([[    0,     0,     0, ...,   569,    14,     2],
#        [    0,     0,     0, ...,    18,   300,     2],
#        [    0,     0,     0, ..., 12518,    83,     2],
#        ...,
#        [    0,     0,     0, ...,   768,  2526,     2],
#        [    0,     0,     0, ...,    42,   220,     2],
#        [    0,     0,     0, ...,   899,  2388,     2]])

# %%
test_y = test_df['score']
scores = model.evaluate(test_x, test_y, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Test accuracy: 0.8672800064086914

# %%
pred = model.predict(test_x)

# %%
from sklearn.metrics import accuracy_score
pred_labels = []
for i in pred:
    if i >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
print("Accuracy of prediction on test set : ", accuracy_score(test_y,pred_labels))
# Out:
# Accuracy of prediction on test set :  0.86728

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(test_y,pred_labels)
print(cm)
# Out:
# [[11187  1313]
#  [ 2005 10495]]

# %%
test_df['pred'] = pred_labels
test_df
test_df.to_csv("test_df_pred_glove_trainable_true.csv")

# %% [markdown]
# **Trainable False**

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU

embedding_layer = Embedding(input_dim=vocab_len, output_dim=embed_vector_len, input_length=max_words, weights=[emb_matrix], trainable=False)

embedding_size=32
model=Sequential()
model.add(embedding_layer)
model.add(GRU(units=50, return_sequences = True, input_shape=(dataset.shape[1],1), activation='tanh'))
#model.add(LSTM(100))
model.add(Dropout(0.6))
model.add(GRU(units=50, input_shape=(dataset.shape[1],1), activation='tanh'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 50)           4960400
#
#  gru_2 (GRU)                 (None, 500, 50)           15300
#
#  dropout_1 (Dropout)         (None, 500, 50)           0
#
#  gru_3 (GRU)                 (None, 50)                15300
#
#  dense_1 (Dense)             (None, 1)                 51
#
# =================================================================
# Total params: 4,991,051
# Trainable params: 30,651
# Non-trainable params: 4,960,400
# _________________________________________________________________
# None

# %%
batch_size=32
model.fit(dataset, y, epochs = 5, batch_size=batch_size, verbose = 'auto')
# Out:
# Epoch 1/5
# 782/782 [==============================] - 184s 232ms/step - loss: 0.5519 - accuracy: 0.7047
# Epoch 2/5
# 782/782 [==============================] - 181s 231ms/step - loss: 0.3895 - accuracy: 0.8287
# Epoch 3/5
# 782/782 [==============================] - 182s 232ms/step - loss: 0.3505 - accuracy: 0.8494
# Epoch 4/5
# 782/782 [==============================] - 182s 232ms/step - loss: 0.3249 - accuracy: 0.8630
# Epoch 5/5
# 782/782 [==============================] - 182s 233ms/step - loss: 0.3075 - accuracy: 0.8730

# %%
scores = model.evaluate(test_x, test_y, verbose=0)
print('Test accuracy:', scores[1])
pred = model.predict(test_x)
pred_labels = []
for i in pred:
    if i >= 0.5:
        pred_labels.append(1)
    else:
        pred_labels.append(0)
print("Accuracy of prediction on test set : ", accuracy_score(test_y,pred_labels))
cm=confusion_matrix(test_y,pred_labels)
print(cm)
test_df['pred'] = pred_labels
test_df.to_csv("test_df_pred_glove_trainable_false.csv")
# Out:
# Test accuracy: 0.8690400123596191
# Accuracy of prediction on test set :  0.86904
# [[10963  1537]
#  [ 1737 10763]]
