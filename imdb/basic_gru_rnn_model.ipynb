# %%
# %cd "OneDrive - National University of Singapore"
# Out:
# C:\Users\wongp\OneDrive - National University of Singapore

# %%
# %cd CS4248/Project/db/
# Out:
# C:\Users\wongp\OneDrive - National University of Singapore\CS4248\Project\db

# %%
import os
import pandas as pd
from nltk.tokenize import word_tokenize
from collections import Counter
from keras.preprocessing import sequence
from sklearn.model_selection import train_test_split

# %% [markdown]
# Convert training data into csv file

# %%
import os
import pandas as pd

pathNeg = "train/neg"
files = os.listdir(pathNeg)
data = []
for file in files:
  if os.path.isfile(os.path.join(pathNeg, file)):
    id = int(file.split("_")[0])
    with open(os.path.join(pathNeg, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 0])

sizeOfNeg = 12500

pathPos = "train/pos"
files = os.listdir(pathPos)
for file in files:
  if os.path.isfile(os.path.join(pathPos, file)):
    id = int(file.split("_")[0]) + sizeOfNeg
    with open(os.path.join(pathPos, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 1])


df = pd.DataFrame(data, columns = ['id', 'text', 'score']).set_index('id').sort_index()
df.to_csv('train.csv')

# %% [markdown]
# Convert testing data into csv file

# %%
pathNeg = "test/neg"
files = os.listdir(pathNeg)
data = []
for file in files:
  if os.path.isfile(os.path.join(pathNeg, file)):
    id = int(file.split("_")[0])
    with open(os.path.join(pathNeg, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 0])

sizeOfNeg = 12500

pathPos = "test/pos"
files = os.listdir(pathPos)
for file in files:
  if os.path.isfile(os.path.join(pathPos, file)):
    id = int(file.split("_")[0]) + sizeOfNeg
    with open(os.path.join(pathPos, file), encoding='utf8') as f:
      lines = f.read()
    data.append([id, lines, 1])


df = pd.DataFrame(data, columns = ['id', 'text', 'score']).set_index('id').sort_index()
df.to_csv('test.csv')

# %% [markdown]
# convert vocab into csv file

# %%
with open("imdb.vocab", encoding='utf8') as f:
  vocab = []
  for line in f:
    vocab.append(line.rstrip())

vocab_df = pd.DataFrame(vocab, columns=['vocab'])
print(vocab_df)
vocab_df.to_csv('vocab_given.csv', index=False)
# Out:
#                    vocab
# 0                    the
# 1                    and
# 2                      a
# 3                     of
# 4                     to
# ...                  ...
# 89522          copywrite
# 89523             artbox
# 89524          kinky-sex
# 89525           urrrghhh
# 89526  investigator-like
#
# [89527 rows x 1 columns]

# %%
from nltk.tokenize import word_tokenize

def tokenizeReview(review):
  review = review.replace('.', ' . ')
  tokens = word_tokenize(review.lower())
  return tokens

# %% [markdown]
# Get vocab from training set

# %%
from collections import Counter
reviews = train_df['text'].tolist()
reviews = list(map(tokenizeReview, reviews))
reviews = [item for review in reviews for item in review]
vdict = Counter(reviews).most_common()

# %%
vocabs = []
for pair in vdict:
  vocabs.append(pair[0])

vocab_df = pd.DataFrame(vocabs, columns=['vocab'])
vocab_df.to_csv('vocab.csv', index=False)
print(vocab_df)
# Out:
#               vocab
# 0               the
# 1                 .
# 2                 ,
# 3               and
# 4                 a
# ...             ...
# 99203    people-and
# 99204         padre
# 99205   unmatchable
# 99206  scenery-wise
# 99207  non-teenager
#
# [99208 rows x 1 columns]

# %% [markdown]
# Read training data and testing data from csv file

# %%
train_df = pd.read_csv('train/train.csv')
test_df = pd.read_csv('test/test.csv')
vocab_df = pd.read_csv('vocab.csv')
print(vocab_df)
# Out:
#               vocab
# 0               the
# 1                 .
# 2                 ,
# 3               and
# 4                 a
# ...             ...
# 99203    people-and
# 99204         padre
# 99205   unmatchable
# 99206  scenery-wise
# 99207  non-teenager
#
# [99208 rows x 1 columns]

# %%
vocab_dict = pd.Series(vocab_df.index + 1, index=vocab_df.vocab).to_dict()
print(vocab_dict)
# Out:
# {'the': 1, '.': 2, ',': 3, 'and': 4, 'a': 5, 'of': 6, 'to': 7, 'is': 8, '/': 9, '>': 10, '<': 11, 'br': 12, 'it': 13, 'in': 14, 'i': 15, 'this': 16, 'that': 17, "'s": 18, 'was': 19, 'as': 20, 'for': 21, 'with': 22, 'movie': 23, 'but': 24, 'film': 25, ')': 26, '(': 27, '``': 28, 'you': 29, 'on': 30, "n't": 31, 'not': 32, "''": 33, 'are': 34, 'he': 35, 'his': 36, 'have': 37, 'be': 38, 'one': 39, '!': 40, 'all': 41, 'at': 42, 'they': 43, 'by': 44, 'an': 45, 'who': 46, 'from': 47, 'so': 48, 'like': 49, 'there': 50, 'her': 51, 'or': 52, 'just': 53, 'do': 54, 'about': 55, 'has': 56, 'if': 57, 'out': 58, '?': 59, 'what': 60, 'some': 61, 'good': 62, 'more': 63, 'when': 64, 'she': 65, 'very': 66, 'would': 67, 'even': 68, 'my': 69, 'no': 70, 'up': 71, 'time': 72, 'can': 73, 'which': 74, 'only': 75, 'story': 76, 'really': 77, 'had': 78, 'their': 79, 'see': 80, 'were': 81, 'we': 82, 'me': 83, 'did': 84, 'does': 85, "'": 86, ':': 87, 'than': 88, '-': 89, 'well': 90, 'much': 91, 'could': 92, 'been': 93, 'people': 94, 'get': 95, 'will': 96, 'also': 97, 'other': 98, 'bad': 99, 'into': 100, 'because': 101, 'great': 102, 'first': 103, 'how': 104, 'him': 105, 'most': 106, 'its': 107, 'made': 108, 'then': 109, 'them': 110, 'way': 111, 'make': 112, 'too': 113, 'any': 114, 'after': 115, 'movies': 116, 'think': 117, 'characters': 118, '*': 119, 'character': 120, 'watch': 121, 'films': 122, ';': 123, 'two': 124, 'many': 125, 'seen': 126, 'being': 127, 'never': 128, 'acting': 129, 'little': 130, 'plot': 131, 'where': 132, 'best': 133, 'love': 134, 'life': 135, 'show': 136, 'know': 137, 'ever': 138, 'here': 139, 'better': 140, 'your': 141, 'man': 142, 'still': 143, 'end': 144, 'over': 145, 'off': 146, 'these': 147, 'say': 148, 'should': 149, 'scene': 150, 'while': 151, 'why': 152, 'scenes': 153, 'such': 154, "'ve": 155, '--': 156, 'go': 157, 'something': 158, 'through': 159, 'back': 160, "'m": 161, 'those': 162, 'watching': 163, 'though': 164, 'now': 165, 'real': 166, 'thing': 167, 'years': 168, 'actors': 169, 'another': 170, 'before': 171, 'nothing': 172, 'new': 173, 'actually': 174, 'work': 175, 'funny': 176, 'makes': 177, 'find': 178, 'director': 179, 'look': 180, 'few': 181, 'old': 182, 'same': 183, 'going': 184, 'again': 185, 'lot': 186, 'part': 187, 'every': 188, '&': 189, 'cast': 190, 'us': 191, 'world': 192, "'re": 193, 'quite': 194, 'got': 195, 'want': 196, 'things': 197, 'pretty': 198, 'young': 199, 'seems': 200, 'around': 201, 'down': 202, 'ca': 203, 'however': 204, 'fact': 205, 'take': 206, 'enough': 207, 'both': 208, 'give': 209, 'may': 210, 'between': 211, 'original': 212, 'horror': 213, 'own': 214, 'big': 215, 'thought': 216, 'series': 217, 'without': 218, 'right': 219, 'times': 220, 'long': 221, 'always': 222, 'gets': 223, 'come': 224, 'point': 225, 'saw': 226, 'role': 227, 'family': 228, 'almost': 229, 'interesting': 230, 'least': 231, 'must': 232, 'action': 233, 'comedy': 234, 'whole': 235, 'bit': 236, 'music': 237, 'done': 238, 'script': 239, 'guy': 240, 'anything': 241, 'minutes': 242, 'might': 243, 'last': 244, 'since': 245, 'performance': 246, 'far': 247, 'feel': 248, "'ll": 249, 'probably': 250, 'am': 251, 'woman': 252, 'kind': 253, 'away': 254, 'girl': 255, 'yet': 256, 'rather': 257, 'worst': 258, 'sure': 259, 'fun': 260, 'anyone': 261, 'making': 262, 'each': 263, 'played': 264, 'found': 265, 'tv': 266, 'having': 267, 'day': 268, 'although': 269, 'especially': 270, 'our': 271, 'course': 272, 'believe': 273, 'comes': 274, 'trying': 275, 'goes': 276, 'hard': 277, 'looks': 278, 'place': 279, 'different': 280, 'book': 281, 'put': 282, "'d": 283, 'maybe': 284, 'someone': 285, '2': 286, 'money': 287, 'ending': 288, 'reason': 289, 'actor': 290, 'everything': 291, 'sense': 292, 'let': 293, 'once': 294, 'shows': 295, 'screen': 296, 'true': 297, 'set': 298, 'dvd': 299, 'worth': 300, 'looking': 301, 'job': 302, 'main': 303, 'watched': 304, 'together': 305, 'everyone': 306, 'plays': 307, 'three': 308, 'john': 309, 'later': 310, 'said': 311, ...

# %%
def convertToIndex(review):
  vec = []
  for word in review:
    if word in vocab_dict:
      vec.append(int(vocab_dict[word]))
    else:
      vec.append(0)
  return vec

# %%
train_df['tokens'] = train_df['text'].apply(tokenizeReview)

# %%
train_df['vec'] = train_df['tokens'].apply(convertToIndex)

# %%
train_df
# Out:
#           id                                               text  score  \
# 0          0  Story of a man who has unnatural feelings for ...      0
# 1          1  Robert DeNiro plays the most unbelievably inte...      0
# 2          2  I saw the capsule comment said "great acting."...      0
# 3          3  If I had not read Pat Barker's 'Union Street' ...      0
# 4          4  This fanciful horror flick has Vincent Price p...      0
# ...      ...                                                ...    ...
# 24995  24995  What's Good About It: Some inventive and genui...      1
# 24996  24996  For years we've been watching every horror fil...      1
# 24997  24997  If you haven't already seen this movie of Mary...      1
# 24998  24998  this movie is the best movie ever it has a lot...      1
# 24999  24999  I always feel strange and guilty saying it (be...      1
#
#                                                   tokens  \
# 0      [story, of, a, man, who, has, unnatural, feeli...
# 1      [robert, deniro, plays, the, most, unbelievabl...
# 2      [i, saw, the, capsule, comment, said, ``, grea...
# 3      [if, i, had, not, read, pat, barker, 's, 'unio...
# 4      [this, fanciful, horror, flick, has, vincent, ...
# ...                                                  ...
# 24995  [what, 's, good, about, it, :, some, inventive...
# 24996  [for, years, we, 've, been, watching, every, h...
# 24997  [if, you, have, n't, already, seen, this, movi...
# 24998  [this, movie, is, the, best, movie, ever, it, ...
# 24999  [i, always, feel, strange, and, guilty, saying...
#
#                                                      vec
# 0      [76, 6, 5, 142, 46, 56, 7518, 1387, 21, 5, 451...
# 1      [649, 5006, 307, 1, 106, 3769, 1076, 9203, 6, ...
# 2      [15, 226, 1, 9586, 906, 311, 28, 102, 129, 2, ...
# 3      [57, 15, 78, 32, 338, 3189, 7720, 18, 34296, 8...
# 4      [16, 16016, 213, 512, 56, 3154, 1789, 397, 5, ...
# ...                                                  ...
# 24995  [60, 18, 62, 55, 13, 87, 61, 4388, 4, 2028, 93...
# 24996  [21, 168, 82, 155, 93, 163, 188, 213, 25, 17, ...
# 24997  [57, 29, 37, 31, 466, 126, 16, 23, 6, 13586, 4...
# 24998  [16, 23, 8, 1, 133, 23, 138, 13, 56, 5, 186, 6...
# 24999  [15, 222, 248, 669, 4, 2490, 653, 13, 27, 101,...
#
# [25000 rows x 5 columns]

# %%
print('Maximum review length: {}'.format(
len(max((train_df['tokens']), key=len))))
print('Minimum review length: {}'.format(
len(min((train_df['tokens']), key=len))))
# Out:
# Maximum review length: 2820
# Minimum review length: 11

# %%
max_words = 500
dataset = sequence.pad_sequences(train_df['vec'], maxlen=max_words)
y = train_df['score']

# %%
X_train, X_val, y_train, y_val = train_test_split(dataset, y, test_size=0.3, stratify=y, random_state = 42)

# %%
vocab_size = len(vocab_dict) + 1
print(vocab_size)
# Out:
# 99208

# %%
from keras import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, GRU
embedding_size=32
model=Sequential()
model.add(Embedding(vocab_size, embedding_size, input_length=max_words))
model.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1), activation='tanh'))
#model.add(LSTM(100))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', 
             optimizer='adam', 
             metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 500, 32)           3174656
#
#  gru (GRU)                   (None, 500, 50)           12600
#
#  dense (Dense)               (None, 500, 1)            51
#
# =================================================================
# Total params: 3,187,307
# Trainable params: 3,187,307
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
batch_size=32
model.fit(X_train, y_train, epochs = 5, batch_size=batch_size, verbose = 'auto')
# Out:
# Epoch 1/5
# 547/547 [==============================] - 71s 128ms/step - loss: 0.6175 - accuracy: 0.6073
# Epoch 2/5
# 547/547 [==============================] - 72s 131ms/step - loss: 0.5136 - accuracy: 0.6806
# Epoch 3/5
# 547/547 [==============================] - 73s 133ms/step - loss: 0.4550 - accuracy: 0.7083
# Epoch 4/5
# 547/547 [==============================] - 72s 132ms/step - loss: 0.4151 - accuracy: 0.7265
# Epoch 5/5
# 547/547 [==============================] - 72s 131ms/step - loss: 0.3953 - accuracy: 0.7287

# %%
scores = model.evaluate(X_val, y_val, verbose=0)
print('Test accuracy:', scores[1])
# Out:
# Test accuracy: 0.6510524153709412

# %%
model.save('basic_gru_model')
# Out:
# WARNING:absl:Found untraced functions such as gru_cell_layer_call_fn, gru_cell_layer_call_and_return_conditional_losses while saving (showing 2 of 2). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: basic_gru_model\assets
# INFO:tensorflow:Assets written to: basic_gru_model\assets
# WARNING:absl:<keras.layers.recurrent.GRUCell object at 0x0000023D12CBCC70> has the same name 'GRUCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.GRUCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
